# %%
import pandas as pd

# %%
df = pd.read_csv("E:/DATA SETS/Advertising.csv")

# %%
df.shape
# Out:
# (200, 4)

# %%
df.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
df.dtypes
# Out:
# TV           float64
# Radio        float64
# Newspaper    float64
# Sales        float64
# dtype: object

# %%
df.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
import seaborn as sns

# %%
sns.pairplot(df,x_vars=['TV','Radio','Newspaper'], y_vars='Sales', height=7,aspect=0.7, kind = 'reg')

# %%
from sklearn.model_selection import train_test_split

# %%
X = df[['TV', 'Radio','Newspaper']]
y=df['Sales']
#Split data
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3, random_state = 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
#instantiaqte model
model =LinearRegression()
#fit model
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)

# %%
y=pd.DataFrame({'Original':y_test,'Predicted':y_pred})

# %%
y.head()
# Out:
#      Original  Predicted
# 58       23.8  21.663183
# 40       16.6  16.441379
# 34        9.5   7.691446
# 102      14.8  17.916317
# 184      17.6  18.670471

# %%
y.head(10).plot(kind="bar", figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# %%
fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(projection='3d')
ax.scatter(df.TV, df.Radio, df.Newspaper, cmap="viridis")

ax.set_xlabel('X:TV')
ax.set_ylabel('Z:Radio')
ax.set_zlabel('Y:Newspaper')
# Out:
# Text(0.5, 0, 'Y:Newspaper')
